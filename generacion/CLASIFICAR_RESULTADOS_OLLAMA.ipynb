# %% [markdown]
# # Classification Analysis of Ollama Model Generations
#
# This notebook processes the generated text from the Ollama model and classifies each generation using an API endpoint. The classification determines whether the text is 'Técnico' (Technical) or 'Plano' (Plain language).
#
# ## Workflow:
# 1. Read the CSV file with model generations
# 2. Extract values from `generation_1` and `generation_2` columns
# 3. Send POST requests to the classification API
# 4. Collect predictions and save to a new CSV file
# 5. Perform data analysis and create visualizations

# %%
# Import required libraries
import pandas as pd
import numpy as np
import requests
import json
import time
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings('ignore')

# Set up plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %% [markdown]
# ## Step 1: Load and Explore the Data
#
# First, let's read the CSV file and examine its structure to understand what data we're working with.

# %%
# Define the CSV file path
csv_file_path = "./GENERATED_TEXTS/ollama__outputs__meta-llama__Llama-3.2-3B-Instruct-FKGD9_Sliding_Window__final_generations.csv"

# Read the CSV file
try:
    df = pd.read_csv(csv_file_path)
    print(f"✅ Successfully loaded CSV file")
    print(f"📊 Data shape: {df.shape}")
    print(f"📋 Columns: {list(df.columns)}")
    
    # Display first few rows
    print("\n🔍 First 3 rows:")
    display(df.head(3))
    
    # Check for missing values
    print("\n❓ Missing values:")
    print(df.isnull().sum())
    
except FileNotFoundError:
    print(f"❌ Error: File '{csv_file_path}' not found. Please check the file path.")
    print("📁 Current working directory files:")
    import os
    print([f for f in os.listdir('.') if f.endswith('.csv')])
except Exception as e:
    print(f"❌ Error loading file: {e}")
# Out:
# ✅ Successfully loaded CSV file
# 📊 Data shape: (30, 5)
# 📋 Columns: ['source_text', 'gen_1', 'gen_2', 'gen_3', 'gen_4']
#
# 🔍 First 3 rows:
#                                          source_text  \
# 0  Background\nBeta‐blockers are an essential par...
# 1  Background\nThe frequency of skin ulceration m...
# 2  Background\nCritically ill patients require re...
#
#                                                gen_1  \
# 0  Beta blockers in children\nBeta blockers are m...
# 1  Treating leg ulcerations in people suffering f...
# 2  Positioning of critically ill people\nWhat is ...
#
#                                                gen_2  \
# 0  Beta‐blocks in children\nBeta blockers are med...
# 1  Treating leg ulceration in people who have sic...
# 2  Positioning of critically ill people\nWhat is ...
#
#                                                gen_3  \
# 0  Beta blockers in children for heart failure\nR...
# 1  Treatment of leg ulceration in people sufferin...
# 2  Positioning of critically ill people\nWhat is ...
#
#                                                gen_4
# 0  Beta blockers for children with heart failure\...
# 1  Treating leg ulceration in people who have sic...
# 2  Positioning of critically ill people\nReview q...
# ❓ Missing values:
# source_text    0
# gen_1          0
# gen_2          0
# gen_3          0
# gen_4          0
# dtype: int64

# %% [markdown]
# ## Step 2: Set up API Configuration
#
# Configure the API endpoint and define helper functions for making requests.

# %%
# API Configuration
API_ENDPOINT = "http://localhost:8001/api/v1/predict"
REQUEST_TIMEOUT = 30  # seconds
DELAY_BETWEEN_REQUESTS = 0.1  # seconds to avoid overwhelming the API

def make_prediction_request(text_value):
    """
    Send a POST request to the prediction API
    
    Args:
        text_value (str): The text to classify
        
    Returns:
        dict: API response with prediction, or None if error
    """
    try:
        payload = {
            "inputs": [str(text_value)]
        }
        
        response = requests.post(
            API_ENDPOINT,
            json=payload,
            timeout=REQUEST_TIMEOUT,
            headers={'Content-Type': 'application/json'}
        )
        
        if response.status_code == 200:
            return response.json()
        else:
            print(f"⚠️ API returned status code: {response.status_code}")
            return None
            
    except requests.exceptions.Timeout:
        print("⏰ Request timeout")
        return None
    except requests.exceptions.ConnectionError:
        print("🔌 Connection error - make sure the API server is running")
        return None
    except Exception as e:
        print(f"❌ Unexpected error: {e}")
        return None

def extract_prediction(api_response):
    """
    Extract prediction from API response
    
    Args:
        api_response (dict): Response from the API
        
    Returns:
        tuple: (prediction_int, prediction_label) or (None, None) if error
    """
    try:
        print('api_response')
        print(api_response)
        if api_response and 'predictions' in api_response:
            prediction_int = api_response['predictions'][0]
            prediction_label = 'Técnico' if prediction_int == 1 else 'Plano'
            return prediction_int, prediction_label
        else:
            return None, None
    except (KeyError, IndexError, TypeError) as e:
        print(f"❌ Error parsing API response: {e}")
        return None, None

# Test API connectivity
print("🔍 Testing API connectivity...")
test_response = make_prediction_request("This is a test message")
if test_response:
    print("✅ API is responding correctly")
    print(f"📝 Sample response: {test_response}")
else:
    print("❌ API test failed. Please ensure the server is running on localhost:8001")
# Out:
# 🔍 Testing API connectivity...
# ✅ API is responding correctly
# 📝 Sample response: {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.0032424673416862615], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}

# %% [markdown]
# ## Step 3: Process Generations and Collect Predictions
#
# Now we'll iterate through each row, extract the generation values, and send them to the API for classification.

# %%
# Prepare data structures to store results
results = []

# Check if the required columns exist
required_columns = ['gen_1', 'gen_2']
available_columns = [col for col in required_columns if col in df.columns]

if not available_columns:
    print("❌ Neither 'gen_1' nor 'gen_2' columns found in the CSV")
    print(f"📋 Available columns: {list(df.columns)}")
else:
    print(f"✅ Found columns: {available_columns}")
    
    # Process each row
    total_requests = len(df) * len(available_columns)
    print(f"🔄 Processing {len(df)} rows with {len(available_columns)} generation(s) each...")
    print(f"📊 Total API requests to make: {total_requests}")
    
    with tqdm(total=total_requests, desc="Processing generations") as pbar:
        for idx, row in df.iterrows():
            row_results = {
                'row_index': idx,
                'source_text': row.get('source_text', ''),
                'target_text': row.get('target_text', '')
            }
            
            # Process each generation column
            for col in available_columns:
                generation_text = row[col]
                
                # Skip if the generation is empty or NaN
                if pd.isna(generation_text) or str(generation_text).strip() == '':
                    row_results[f'{col}_prediction_int'] = None
                    row_results[f'{col}_prediction_label'] = None
                    row_results[f'{col}_text'] = ''
                    print(f"⏭️ Skipping empty generation at row {idx}, column {col}")
                else:
                    # Make API request
                    api_response = make_prediction_request(generation_text)
                    pred_int, pred_label = extract_prediction(api_response)
                    
                    # Store results
                    row_results[f'{col}_prediction_int'] = pred_int
                    row_results[f'{col}_prediction_label'] = pred_label
                    row_results[f'{col}_text'] = str(generation_text)
                    
                    # Small delay to avoid overwhelming the API
                    time.sleep(DELAY_BETWEEN_REQUESTS)
                
                pbar.update(1)
            
            results.append(row_results)
    
    print(f"✅ Completed processing {len(results)} rows")
# Out:
# ✅ Found columns: ['gen_1', 'gen_2']
# 🔄 Processing 30 rows with 2 generation(s) each...
# 📊 Total API requests to make: 60
# Processing generations:   0%|          | 0/60 [00:00<?, ?it/s]
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.010113689143824987], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.021120936823665958], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.008001792044499677], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.06483204158005842], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.008001792044499677], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.06483204158005842], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.005482150879341196], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9277901963341998], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.005482150879341196], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9277901963341998], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.017387438645892893], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.10047695938922353], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.017387438645892893], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.10047695938922353], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.000578773710581209], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.009693847261827856], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.000578773710581209], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.009693847261827856], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.3918270394708183], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9735731969542888], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.3918270394708183], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9735731969542888], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9650545865511848], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9251160473492269], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9650545865511848], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9251160473492269], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.8626745121216755], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.18635623048263306], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.8626745121216755], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.18635623048263306], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.5996841294708175], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.2913783237313855], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.5996841294708175], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.2913783237313855], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.6907977721684073], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.48827772921280566], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.6907977721684073], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.48827772921280566], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.0211384932257944], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.10508709615660836], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.0211384932257944], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.10508709615660836], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.519528426843121], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.8720693051066803], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.519528426843121], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.8720693051066803], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.3832717448717397], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.04897805069112712], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.3832717448717397], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.04897805069112712], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9751367975175266], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.968986733891099], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9751367975175266], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.968986733891099], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.7554612265630931], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.8624816286860809], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.7554612265630931], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.8624816286860809], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.7542477361722357], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.7630460893561251], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.7542477361722357], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.7630460893561251], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9999951551165817], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.985257652381066], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9999951551165817], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.985257652381066], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.03156790255207691], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9677878623014314], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.03156790255207691], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9677878623014314], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.25569128783242684], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.8996046200989434], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.25569128783242684], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.8996046200989434], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.8634316953349821], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.7404504918668207], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.8634316953349821], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.7404504918668207], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.20634936451703623], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.220083707991699], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.20634936451703623], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.220083707991699], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.6958014503616198], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.1872836797259527], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.6958014503616198], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.1872836797259527], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.30117242463627647], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.2926870668660224], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.30117242463627647], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.2926870668660224], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.011943081646873674], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.0036097883792899806], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.011943081646873674], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.0036097883792899806], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9059079005369078], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9219919650996377], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9059079005369078], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9219919650996377], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.006384453778073641], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9132039912879066], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.006384453778073641], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9132039912879066], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9626721880031573], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9660965635892618], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9626721880031573], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9660965635892618], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.05322497921007192], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [9.529970784422479e-06], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.05322497921007192], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [9.529970784422479e-06], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.7290895022286508], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9552299870701467], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.7290895022286508], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.9552299870701467], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.5602834535314882], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.020212006745615786], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [1], 'scores': [0.5602834535314882], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# api_response
# {'errors': None, 'version': '0.1.0', 'predictions': [0], 'scores': [0.020212006745615786], 'metadata': {'model_version': '0.1.0', 'metrics': {'accuracy': 0.9613733905579399, 'recall': 0.9392523364485982, 'f1_score': 0.9571428571428572, 'pr_auc': 0.9953511568055804, 'roc_auc': 0.9960688325174306}}}
# ✅ Completed processing 30 rows
# ✅ Completed processing 30 rows

# %% [markdown]
# ## Step 4: Create and Save Results DataFrame
#
# Convert the collected results into a DataFrame and save it as a CSV file.

# %%
# Create DataFrame from results
results_df = pd.DataFrame(results)

# Display results summary
print("📊 Results Summary:")
print(f"Total rows processed: {len(results_df)}")
print(f"Columns in results: {list(results_df.columns)}")

# Show first few rows of results
print("\n🔍 First 3 rows of results:")
display(results_df.head(3))

# Save to CSV file
output_filename = csv_file_path.replace('.csv', '_classification.csv')
results_df.to_csv(output_filename, index=False)
print(f"💾 Results saved to: {output_filename}")

# Display classification statistics
print("\n📈 Classification Statistics:")
for col in available_columns:
    label_col = f'{col}_prediction_label'
    if label_col in results_df.columns:
        print(f"\n{col.replace('_', ' ').title()}:")
        counts = results_df[label_col].value_counts(dropna=False)
        print(counts)
        
        # Calculate percentages
        percentages = results_df[label_col].value_counts(normalize=True, dropna=False) * 100
        print("Percentages:")
        for label, pct in percentages.items():
            print(f"  {label}: {pct:.1f}%")
# Out:
# 📊 Results Summary:
# Total rows processed: 30
# Columns in results: ['row_index', 'source_text', 'target_text', 'gen_1_prediction_int', 'gen_1_prediction_label', 'gen_1_text', 'gen_2_prediction_int', 'gen_2_prediction_label', 'gen_2_text']
#
# 🔍 First 3 rows of results:
#    row_index                                        source_text target_text  \
# 0          0  Background\nBeta‐blockers are an essential par...
# 1          1  Background\nThe frequency of skin ulceration m...
# 2          2  Background\nCritically ill patients require re...
#
#    gen_1_prediction_int gen_1_prediction_label  \
# 0                     0                  Plano
# 1                     0                  Plano
# 2                     0                  Plano
#
#                                           gen_1_text  gen_2_prediction_int  \
# 0  Beta blockers in children\nBeta blockers are m...                     0
# 1  Treating leg ulcerations in people suffering f...                     0
# 2  Positioning of critically ill people\nWhat is ...                     1
#
#   gen_2_prediction_label                                         gen_2_text
# 0                  Plano  Beta‐blocks in children\nBeta blockers are med...
# 1                  Plano  Treating leg ulceration in people who have sic...
# 2                Técnico  Positioning of critically ill people\nWhat is ...
# 💾 Results saved to: ./GENERATED_TEXTS/ollama__outputs__meta-llama__Llama-3.2-3B-Instruct-FKGD9_Sliding_Window__final_generations_classification.csv
#
# 📈 Classification Statistics:
#
# Gen 1:
# gen_1_prediction_label
# Plano      15
# Técnico    15
# Name: count, dtype: int64
# Percentages:
#   Plano: 50.0%
#   Técnico: 50.0%
#
# Gen 2:
# gen_2_prediction_label
# Plano      15
# Técnico    15
# Name: count, dtype: int64
# Percentages:
#   Plano: 50.0%
#   Técnico: 50.0%

# %% [markdown]
# ## Step 5: Data Analysis and Visualizations
#
# Now let's perform comprehensive analysis of the classification results and create visualizations.

# %%
# Set up the plotting environment
plt.rcParams['figure.figsize'] = (12, 8)

# Create subplots for comprehensive analysis
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('Classification Analysis of Model Generations', fontsize=16, fontweight='bold')

# Plot 1: Distribution of predictions for each generation
ax1 = axes[0, 0]
if len(available_columns) == 2:
    gen1_counts = results_df['gen_1_prediction_label'].value_counts()
    gen2_counts = results_df['gen_2_prediction_label'].value_counts()
    
    x = np.arange(len(gen1_counts.index))
    width = 0.35
    
    ax1.bar(x - width/2, gen1_counts.values, width, label='Generation 1', alpha=0.8)
    ax1.bar(x + width/2, gen2_counts.values, width, label='Generation 2', alpha=0.8)
    ax1.set_xlabel('Classification')
    ax1.set_ylabel('Count')
    ax1.set_title('Distribution of Classifications by Generation')
    ax1.set_xticks(x)
    ax1.set_xticklabels(gen1_counts.index)
    ax1.legend()
    ax1.grid(True, alpha=0.3)
else:
    # Single generation column
    col = available_columns[0]
    label_col = f'{col}_prediction_label'
    counts = results_df[label_col].value_counts()
    
    ax1.bar(counts.index, counts.values, alpha=0.8)
    ax1.set_xlabel('Classification')
    ax1.set_ylabel('Count')
    ax1.set_title(f'Distribution of Classifications - {col.replace("_", " ").title()}')
    ax1.grid(True, alpha=0.3)

# Plot 2: Pie chart of overall classification distribution
ax2 = axes[0, 1]
all_predictions = []
for col in available_columns:
    label_col = f'{col}_prediction_label'
    all_predictions.extend(results_df[label_col].dropna().tolist())

if all_predictions:
    unique_labels, counts = np.unique(all_predictions, return_counts=True)
    ax2.pie(counts, labels=unique_labels, autopct='%1.1f%%', startangle=90)
    ax2.set_title('Overall Classification Distribution')

# Plot 3: Agreement between generations (if both exist)
ax3 = axes[1, 0]
if len(available_columns) == 2:
    # Create agreement analysis
    agreement_data = results_df[['gen_1_prediction_label', 'gen_2_prediction_label']].dropna()
    
    if len(agreement_data) > 0:
        agreement = (agreement_data['gen_1_prediction_label'] == 
                    agreement_data['gen_2_prediction_label']).mean()
        
        agreement_counts = [
            len(agreement_data[agreement_data['gen_1_prediction_label'] == 
                              agreement_data['gen_2_prediction_label']]),
            len(agreement_data[agreement_data['gen_1_prediction_label'] != 
                              agreement_data['gen_2_prediction_label']])
        ]
        
        ax3.bar(['Agreement', 'Disagreement'], agreement_counts, 
                color=['lightgreen', 'lightcoral'], alpha=0.8)
        ax3.set_ylabel('Count')
        ax3.set_title(f'Agreement Between Generations\n(Agreement Rate: {agreement:.1%})')
        ax3.grid(True, alpha=0.3)
        
        # Add percentage labels on bars
        for i, count in enumerate(agreement_counts):
            percentage = count / len(agreement_data) * 100
            ax3.text(i, count + max(agreement_counts) * 0.01, f'{percentage:.1f}%', 
                    ha='center', va='bottom', fontweight='bold')
else:
    ax3.text(0.5, 0.5, 'Agreement analysis requires\nboth generation columns', 
             ha='center', va='center', transform=ax3.transAxes, fontsize=12)
    ax3.set_title('Generation Agreement Analysis')

# Plot 4: Text length distribution by classification
ax4 = axes[1, 1]
if available_columns:
    # Calculate text lengths
    tech_lengths = []
    plain_lengths = []
    
    for col in available_columns:
        text_col = f'{col}_text'
        label_col = f'{col}_prediction_label'
        
        if text_col in results_df.columns and label_col in results_df.columns:
            tech_texts = results_df[results_df[label_col] == 'Técnico'][text_col].dropna()
            plain_texts = results_df[results_df[label_col] == 'Plano'][text_col].dropna()
            
            tech_lengths.extend([len(str(text)) for text in tech_texts])
            plain_lengths.extend([len(str(text)) for text in plain_texts])
    
    if tech_lengths and plain_lengths:
        ax4.hist([tech_lengths, plain_lengths], bins=20, alpha=0.7, 
                label=['Técnico', 'Plano'], color=['red', 'blue'])
        ax4.set_xlabel('Text Length (characters)')
        ax4.set_ylabel('Frequency')
        ax4.set_title('Text Length Distribution by Classification')
        ax4.legend()
        ax4.grid(True, alpha=0.3)
    else:
        ax4.text(0.5, 0.5, 'No valid text data\nfor length analysis', 
                ha='center', va='center', transform=ax4.transAxes, fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 6: Detailed Statistical Analysis

# %%
# Detailed statistical analysis
print("📊 DETAILED STATISTICAL ANALYSIS")
print("=" * 50)

# 1. Basic statistics
print("\n1. BASIC STATISTICS:")
print("-" * 20)
total_valid_predictions = 0
for col in available_columns:
    label_col = f'{col}_prediction_label'
    valid_predictions = results_df[label_col].dropna()
    total_valid_predictions += len(valid_predictions)
    print(f"{col.replace('_', ' ').title()}: {len(valid_predictions)} valid predictions")

print(f"Total valid predictions: {total_valid_predictions}")

# 2. Classification distribution
print("\n2. CLASSIFICATION DISTRIBUTION:")
print("-" * 30)
all_predictions = []
for col in available_columns:
    label_col = f'{col}_prediction_label'
    all_predictions.extend(results_df[label_col].dropna().tolist())

if all_predictions:
    from collections import Counter
    pred_counts = Counter(all_predictions)
    for label, count in pred_counts.items():
        percentage = (count / len(all_predictions)) * 100
        print(f"{label}: {count} ({percentage:.1f}%)")

# 3. Error analysis
print("\n3. ERROR ANALYSIS:")
print("-" * 15)
failed_requests = 0
for col in available_columns:
    label_col = f'{col}_prediction_label'
    failed_count = results_df[label_col].isna().sum()
    failed_requests += failed_count
    print(f"Failed predictions for {col}: {failed_count}")

if total_valid_predictions + failed_requests > 0:
    success_rate = (total_valid_predictions / (total_valid_predictions + failed_requests)) * 100
    print(f"Overall success rate: {success_rate:.1f}%")

# 4. Agreement analysis (if applicable)
if len(available_columns) == 2:
    print("\n4. AGREEMENT ANALYSIS:")
    print("-" * 20)
    
    valid_pairs = results_df[['gen_1_prediction_label', 'gen_2_prediction_label']].dropna()
    
    if len(valid_pairs) > 0:
        agreement = (valid_pairs['gen_1_prediction_label'] == 
                    valid_pairs['gen_2_prediction_label']).mean()
        
        print(f"Agreement rate: {agreement:.1%}")
        
        # Confusion matrix style analysis
        print("\nDetailed agreement breakdown:")
        for label1 in ['Técnico', 'Plano']:
            for label2 in ['Técnico', 'Plano']:
                count = len(valid_pairs[
                    (valid_pairs['gen_1_prediction_label'] == label1) & 
                    (valid_pairs['gen_2_prediction_label'] == label2)
                ])
                print(f"Gen1={label1}, Gen2={label2}: {count}")

# 5. Text length analysis
print("\n5. TEXT LENGTH ANALYSIS:")
print("-" * 25)
for col in available_columns:
    text_col = f'{col}_text'
    label_col = f'{col}_prediction_label'
    
    if text_col in results_df.columns and label_col in results_df.columns:
        print(f"\n{col.replace('_', ' ').title()}:")
        
        for label in ['Técnico', 'Plano']:
            texts = results_df[results_df[label_col] == label][text_col].dropna()
            if len(texts) > 0:
                lengths = [len(str(text)) for text in texts]
                avg_length = np.mean(lengths)
                std_length = np.std(lengths)
                print(f"  {label}: avg length = {avg_length:.0f} ± {std_length:.0f} characters")
# Out:
# 📊 DETAILED STATISTICAL ANALYSIS
# ==================================================
#
# 1. BASIC STATISTICS:
# --------------------
# Gen 1: 30 valid predictions
# Gen 2: 30 valid predictions
# Total valid predictions: 60
#
# 2. CLASSIFICATION DISTRIBUTION:
# ------------------------------
# Plano: 30 (50.0%)
# Técnico: 30 (50.0%)
#
# 3. ERROR ANALYSIS:
# ---------------
# Failed predictions for gen_1: 0
# Failed predictions for gen_2: 0
# Overall success rate: 100.0%
#
# 4. AGREEMENT ANALYSIS:
# --------------------
# Agreement rate: 66.7%
#
# Detailed agreement breakdown:
# Gen1=Técnico, Gen2=Técnico: 10
# Gen1=Técnico, Gen2=Plano: 5
# Gen1=Plano, Gen2=Técnico: 5
# Gen1=Plano, Gen2=Plano: 10
#
# 5. TEXT LENGTH ANALYSIS:
# -------------------------
#
# Gen 1:
#   Técnico: avg length = 13535 ± 3820 characters
#   Plano: avg length = 10691 ± 4935 characters
#
# Gen 2:
#   Técnico: avg length = 11999 ± 4373 characters
#   Plano: avg length = 12503 ± 4908 characters
